# %%
import pandas as pd
import glob
import os

# %%
path = r'Tweets'
all_files = glob.glob(os.path.join(path , "*.txt"))
all_files
# Out:
# ['Tweets\\bbchealth.txt',
#  'Tweets\\cbchealth.txt',
#  'Tweets\\cnnhealth.txt',
#  'Tweets\\everydayhealth.txt',
#  'Tweets\\foxnewshealth.txt',
#  'Tweets\\gdnhealthcare.txt',
#  'Tweets\\goodhealth.txt',
#  'Tweets\\KaiserHealthNews.txt',
#  'Tweets\\latimeshealth.txt',
#  'Tweets\\msnhealthnews.txt',
#  'Tweets\\NBChealth.txt',
#  'Tweets\\nprhealth.txt',
#  'Tweets\\nytimeshealth.txt',
#  'Tweets\\reuters_health.txt',
#  'Tweets\\usnewshealth.txt',
#  'Tweets\\wsjhealth.txt']

# %%
li = []
for filename in all_files:
    try:
        df = pd.read_csv(filename, sep='|', header=None, names=['ID', 'Date', 'Tweet'])
        li.append(df)
    except:
        continue
data = pd.concat(li, axis=0, ignore_index=True)
data.head()
# Out:
#                    ID                            Date  \
# 0  585978391360221184  Thu Apr 09 01:31:50 +0000 2015
# 1  585947808772960257  Wed Apr 08 23:30:18 +0000 2015
# 2  585947807816650752  Wed Apr 08 23:30:18 +0000 2015
# 3  585866060991078401  Wed Apr 08 18:05:28 +0000 2015
# 4  585794106170839041  Wed Apr 08 13:19:33 +0000 2015
#
#                                                Tweet
# 0  Breast cancer risk test devised http://bbc.in/...
# 1  GP workload harming care - BMA poll http://bbc...
# 2  Short people's 'heart risk greater' http://bbc...
# 3  New approach against HIV 'promising' http://bb...
# 4  Coalition 'undermined NHS' - doctors http://bb...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22290 entries, 0 to 22289
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      22290 non-null  int64
#  1   Date    22290 non-null  object
#  2   Tweet   22290 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 522.5+ KB

# %%
X = data[['Tweet']]
X.head()
# Out:
#                                                Tweet
# 0  Breast cancer risk test devised http://bbc.in/...
# 1  GP workload harming care - BMA poll http://bbc...
# 2  Short people's 'heart risk greater' http://bbc...
# 3  New approach against HIV 'promising' http://bb...
# 4  Coalition 'undermined NHS' - doctors http://bb...

# %%
with open('stopwords.txt', encoding='utf8') as stopwords_file:
    stopwords = stopwords_file.readlines()
stopwords = [line.replace('\n', '') for line in stopwords]
stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
# ...

# %%
from nltk import word_tokenize
import nltk
import re
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kavia\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
dataset = pd.DataFrame(columns=['title_body'])
for index, row in X.iterrows():
    title_body_tokenized = word_tokenize(row['Tweet'])
    title_body_tokenized_filtered = [w.lower() for w in title_body_tokenized if not w.lower() in stopwords]
    text = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", ' '.join(title_body_tokenized_filtered))
    text = re.sub('[^\w\s]', '', text)
    text = re.sub("\d+", "", text)
    dataset.loc[index] = {
        'title_body': text,
    }

# %%
dataset
# Out:
#                                               title_body
# 0                          breast cancer risk devised
# 1                     workload harming care  bma poll
# 2                          short people s heart risk
# 3                             approach hiv promising
# 4                  coalition undermined nhs   doctors
# ...                                                  ...
# 22285  rt  annamedaris   dance party  fitness class  ...
# 22286                                        gray  s
# 22287                        nervous  nerves anxiety
# 22288  rt  leonardkl  millions signed health insuranc...
# 22289  rt  leonardkl   healthinsurance time jan   d l...
#
# [22290 rows x 1 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(dataset['title_body'])
# Out:
# TfidfVectorizer()

# %%
X = vectorizer.transform(dataset['title_body'])

# %%
X
# Out:
# <22290x16816 sparse matrix of type '<class 'numpy.float64'>'
# 	with 128005 stored elements in Compressed Sparse Row format>

# %%
import umap
reducer = umap.UMAP(n_components=1000)

# %%
X_reduced = reducer.fit_transform(X)

# %%
import numpy as np
np.shape(X_reduced)
# Out:
# (22290, 1000)

# %%
from sklearn.cluster import MeanShift, SpectralClustering, KMeans

# %%
msh = KMeans(n_clusters=6)
msh.fit(X_reduced)
# Out:
# KMeans(n_clusters=6)

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X, msh.labels_)
# Out:
# 0.0017803274150867648

# %%
dataset['Cluster'] = msh.labels_

# %%
import numpy as np
np.unique(msh.labels_, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  array([6980, 4142, 4881, 3907,   44, 2336], dtype=int64))

# %%
dataset[dataset['Cluster'] == 2]
# Out:
#                                               title_body  Cluster
# 2                          short people s heart risk            2
# 13                                 strenuous runs bad           2
# 30                            blood s syndrome hailed           2
# 32                                 paracetamol  pain            2
# 61                         fitness linked cancer risk           2
# ...                                                  ...      ...
# 22260          psychological hiv devastating disease            2
# 22261                         people copd  nutrition            2
# 22271  cold days winter   tobyamidor  foods improve m...        2
# 22287                        nervous  nerves anxiety            2
# 22288  rt  leonardkl  millions signed health insuranc...        2
#
# [4881 rows x 2 columns]

# %%
from collections import Counter

# %%
Counter(" ".join(dataset[dataset['Cluster'] == 1]["title_body"]).split(' ')).most_common(20)
# Out:
# [('', 24423),
#  ('healthtalk', 843),
#  ('rt', 776),
#  ('s', 498),
#  ('a', 359),
#  ('weight', 283),
#  ('foods', 270),
#  ('diet', 258),
#  ('nt', 249),
#  ('healthy', 213),
#  ('everydayhealth', 202),
#  ('eat', 197),
#  ('amp', 189),
#  ('health', 187),
#  ('eating', 171),
#  ('re', 155),
#  ('fat', 152),
#  ('q', 135),
#  ('eatsmartbd', 132),
#  ('food', 131)]

# %%
Counter(" ".join(dataset[dataset['Cluster'] == 5]["title_body"]).split(' ')).most_common(20)
# Out:
# [('', 9393),
#  ('ebola', 1805),
#  ('us', 324),
#  ('s', 199),
#  ('africa', 198),
#  ('health', 189),
#  ('liberia', 189),
#  ('leone', 171),
#  ('sierra', 167),
#  ('patient', 159),
#  ('west', 158),
#  ('hospital', 139),
#  ('rt', 131),
#  ('nurse', 128),
#  ('outbreak', 114),
#  ('virus', 106),
#  ('fight', 94),
#  ('dallas', 86),
#  ('video', 75),
#  ('texas', 75)]

# %%
# MasoudKaviani.ir
