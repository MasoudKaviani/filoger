# %%
import requests
from lxml import html

# %%
page = requests.get('https://ganjoor.net/khayyam/robaee/sh1/')

# %%
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html lang="fa-IR" dir="rtl">\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\r\n    <title>\r\n        \xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1 &raquo; \xd8\xae\xdb\x8c\xd8\xa7\xd9\x85 \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c\xd8\xa7\xd8\xaa \xc2\xbb \xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c \xd8\xb4\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87\xd9\x94 \xdb\xb1\r\n    </title>\r\n        <script type="application/ld+json">\r\n        {\r\n         "@context": "http://schema.org",\r\n "@type": "BreadcrumbList",\r\n "itemListElement": [\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 1,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/",\r\n         "name": "\xd8\xae\xdb\x8c\xd8\xa7\xd9\x85", \r\n         "image": "https://ganjgah.ir/api/ganjoor/poet/image/khayyam.png"\r\n     }\r\n    },\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 2,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/robaee/",\r\n         "name": "\xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c\xd8\xa7\xd8\xaa", \r\n         "image": "https://i.ganjoor.net/cat.png"\r\n     }\r\n    },\r\n     {\r\n     "@type": "ListItem",\r\n     "position": 3,\r\n     "item": {\r\n         "@id": "https://ganjoor.net/khayyam/robaee/sh1/",\r\n         "name": "\xd8\xb1\xd8\xa8\xd8\xa7\xd8\xb9\xdb\x8c \xd8\xb4\xd9\x85\xd8\xa7\xd8\xb1\xd9\x87\xd9\x94 \xdb\xb1", \r\n         "image": "https://i.ganjoor.net/poem.png"\r\n     }\r\n    }\r\n]\r\n\r\n        }\r\n        </script>\r\n    <link href="/dist/skin/blue.monday/css/jplayer.blue.monday.min.css" rel="stylesheet" type="text/css" />\r\n    <link href="/css/p6.css" rel="stylesheet" type="text/css" />\r\n    <link href="/css/fab.css" rel="stylesheet" type="text/css" />\r\n    <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />\r\n    <link rel="search" type="application/opensearchdescription+xml" title="\xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1" href="https://ganjoor.net/search.xml" />\r\n   \r\n</head>\r\n<body>\r\n\r\n\r\n        \r\n<div id="hdr2" class="clearfix">\r\n    <h1><a href="/" title="\xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1"><img src="/image/ganjadabk.gif" alt="\xda\xaf\xd9\x86\xd8\xac\xd9\x88\xd8\xb1" /></a></h1>\r\n    <div class="actionbox">\r\n        <form action="/search" method="get" id="searchform">\r\n            <input type="text" name="s" id="s" class="inputText" value="" placeholder="\xd8\xac\xd8\xb3\xd8\xaa\xd8\xac\xd9\x88" />\r\n            <select name="author" id="author">\r\n\r\n                        <option value="0">\xd8\xaf\xd8\xb1 \xd8\xa2\xd8\xab\xd8\xa7\xd8\xb1 \xd9\x87\xd9\x85\xd9\x87 \xd8\xb4\xd8\xa7\xd8\xb9\xd8\xb1\xd8\xa7\xd9\x86</option>\r\n                            <option value="57">\xd8\xa7\xd8\xa8\xd9\x86 \xd8\xad\xd8\xb3\xd8\xa7\xd9\x85 \xd8\xae\xd9\x88\xd8\xb3\xd9\x81\xdb\x8c</option>\r\n                            <option value="26">\xd8\xa7\xd8\xa8\xd9\x88\xd8\xb3\xd8\xb9\xdb\x8c\xd8\xaf \xd8\xa7\xd8\xa8\xd9\x88\xd8\xa7\xd9\x84\xd8\xae\xdb\x8c\xd8\xb1</option>\r\n                            <option value="63">\xd8\xa7\xd8\xb2\xd8\xb1\xd9\x82\xdb\x8c \xd9\x87\xd8\xb1\xd9\x88\xdb\x8c</option>\r\n                            <option value="52">\xd8\xa7\xd8\xb3\xd8\xaf\xdb\x8c \xd8\xaa\xd9\x88\xd8\xb3\xdb\x8c</option>\r\n                            <option value="42">\xd8\xa7\xd9\x82\xd8\xa8\xd8\xa7\xd9\x84 \xd9\x84\xd8\xa7\xd9\x87\xd9\x88\xd8\xb1\xdb\x8c</option>\r\n                            <option value="64">\xd8\xa7\xd9\x85\xdb\x8c\xd8\xb1 \xd9\x85\xd8\xb9\xd8\xb2\xdb\x8c</option>\r\n                            <option value="34">\xd8\xa7\xd9\x85\xdb\x8c\xd8\xb1\xd8\xae\xd8\xb3\xd8\xb1\xd9\x88 \xd8\xaf\xd9\x87\xd9\x84\xd9\x88\xdb\x8c</option>\r\n                            <option value="18">\xd8\xa7\xd9\x86\xd9\x88\xd8\xb1\xdb\x8c</option>\r\n                            <option value="19">\xd8\xa7\xd9\x88\xd8\xad\xd8 ...

# %%
tree = html.fromstring(page.content)

# %%
tree
# Out:
# <Element html at 0x7f252902c110>

# %%
tree.xpath('//div[@class="b"]/div/p/text()')
# Out:
# ['برخیز بتا بیا ز بهر دل ما',
#  'حل کن به جمال خویشتن مشکل ما',
#  'یک کوزه شراب تا به هم نوش کنیم',
#  'زآن پیش که کوزه\u200cها کنند از گل ما']

# %%
for i in range(1, 179):
    page = requests.get('https://ganjoor.net/khayyam/robaee/sh' + str(i) + '/')
    tree = html.fromstring(page.content)
    with open('khayyam.txt', 'a') as f:
        for t in tree.xpath('//div[@class="b"]/div/p/text()'):
            f.write('|' + str(t.replace('\u200c', ' ')) + '\n')
